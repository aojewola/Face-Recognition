# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv.imread("mypix.jpg")
plt.imshow(img)

# %%
img
# Out:
# array([[[153, 159, 158],
#         [152, 158, 157],
#         [155, 163, 162],
#         ...,
#         [185, 193, 162],
#         [188, 196, 165],
#         [186, 194, 163]],
#
#        [[152, 158, 157],
#         [147, 153, 152],
#         [151, 159, 158],
#         ...,
#         [185, 193, 162],
#         [188, 196, 165],
#         [187, 195, 164]],
#
#        [[161, 167, 166],
#         [154, 160, 159],
#         [157, 165, 164],
#         ...,
#         [189, 197, 166],
#         [189, 197, 166],
#         [189, 195, 164]],
#
#        ...,
#
#        [[244, 218, 188],
#         [243, 216, 189],
#         [233, 206, 180],
#         ...,
#         [167, 173, 162],
#         [163, 168, 159],
#         [165, 170, 161]],
#
#        [[236, 211, 177],
#         [234, 211, 179],
#         [236, 212, 182],
#         ...,
#         [169, 175, 164],
#         [174, 179, 170],
#         [167, 172, 163]],
#
#        [[232, 210, 174],
#         [235, 213, 178],
#         [233, 210, 178],
#         ...,
#         [165, 171, 160],
#         [174, 182, 172],
#         [166, 174, 164]]], dtype=uint8)

# %%
img.shape
# Out:
# (2560, 1920, 3)

# %%
imag = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
image = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(image)

# %% [markdown]
# #### Using CascadeClassifier

# %%
face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
faces = face_cascade.detectMultiScale(img, 1.1, 4)

for (x,y,w,h) in faces:
    cv.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 40)

plt.imshow(image)
